# %%
import matplotlib.pyplot as plt


BSWN = [3271150, 3342000, 7246500]
BSUNC = [3360150, 3160250, 7072750]
BSPPI = [3180600, 3278700, 7162750]

# Positions for the groups
positions = range(3)

# Width of the bars
width = 0.2

plt.bar(positions, BSWN, width=width, label='BubbleSortWhileNeeded')
plt.bar([pos + width for pos in positions], BSUNC, width=width, label='BubbleSortUntilNoChange')
plt.bar([pos + 2 * width for pos in positions], BSPPI, width=width, label='BubbleSortPassPerItem')

plt.xticks([pos + width for pos in positions], ['Integer', 'Double', 'String'])

plt.xlabel('Data type')
plt.ylabel('Execution Time')
plt.title('Data type')
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt


BSWN = [5079400, 18921100, 79704650]
BSUNC = [5169950, 19895550, 80811450]
BSPPI = [5174500, 20629450, 85552000]

# Positions for the groups
positions = range(3)

# Width of the bars
width = 0.2

plt.bar(positions, BSWN, width=width, label='BubbleSortWhileNeeded')
plt.bar([pos + width for pos in positions], BSUNC, width=width, label='BubbleSortUntilNoChange')
plt.bar([pos + 2 * width for pos in positions], BSPPI, width=width, label='BubbleSortPassPerItem')

plt.xticks([pos + width for pos in positions], ['1024', '2048', '4096'])

plt.xlabel('Array size')
plt.ylabel('Execution Time')
plt.title('Array sizes')
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt


BSWN = [5210800, 8600, 6737150]
BSUNC = [5173100, 10400, 5278700]
BSPPI = [6013850, 8400, 4728700]

# Positions for the groups
positions = range(3)

# Width of the bars
width = 0.2

plt.bar(positions, BSWN, width=width, label='BubbleSortWhileNeeded')
plt.bar([pos + width for pos in positions], BSUNC, width=width, label='BubbleSortUntilNoChange')
plt.bar([pos + 2 * width for pos in positions], BSPPI, width=width, label='BubbleSortPassPerItem')

plt.xticks([pos + width for pos in positions], ['Random', 'Sorted', 'Inverted Sorted'])

plt.xlabel('Order')
plt.ylabel('Execution Time')
plt.title('Initial array state')
plt.legend(loc='upper center')

plt.show()
